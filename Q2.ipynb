# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from dataload4ap2 import grapes
a=grapes()
a.r_w
# Out:
# Initializing appendix2
