# %% [markdown]
# # 问题：分析附件1中两组评酒员的评价结果有无显著性差异，哪一组结果更可信？

# %%
# %load_ext autoreload
# %autoreload 2
from data_load4ap1 import appendix1
a1=appendix1()

# %% [markdown]
# 数据集太复杂了，我只能手搓了

# %%
df_r_1,df_w_1,df_r_2,df_w_2=a1.sum_group()
r_1_p=df_r_1.T.copy()
r_2_p=df_r_2.T.copy()
w_1_p=df_w_1.T.copy()
w_2_p=df_w_2.T.copy()

# %%
#tmp=a1.standardization(w_2_p.T)
a1.anova(r_1_p)
# Out:
# 组间变异量：341.721811
# 组内变异量：96.309117
# 自由度k:9
# 自由度n:17
# F值:6.702
# f: 0.9995881041023327
# p值:0.000823791795334649634696688736

# %%
w_2_p.head()
# Out:
#        p1  p2  p3  p4  p5  p6  p7  p8  p9  p10
# w_2_1  84  78  82  75  79  84  81  69  75   72
# w_2_2  79  76  77  85  77  79  80  59  76   70
# w_2_3  85  74  71  87  79  79  80  45  83   73
# w_2_4  84  78  74  83  69  82  84  66  77   72
# w_2_5  83  79  79  80  77  87  82  73  84   91

# %%
df_r_1
# Out:
#      r_1_1  r_1_2  r_1_3  r_1_4  r_1_5  r_1_6  r_1_7  r_1_8  r_1_9  r_1_10  \
# p1      51     71     80     52     74     72     63     64     77      67
# p2      66     81     85     64     74     69     70     76     78      82
# p3      49     86     89     65     72     71     76     65     76      83
# p4      54     74     76     66     62     61     64     65     82      68
# p5      77     91     69     58     84     82     59     76     85      75
# p6      61     80     89     82     63     69     84     72     90      73
# p7      72     83     73     76     68     69     72     69     76      75
# p8      61     79     83     63     84     64     59     85     92      68
# p9      74     85     84     83     81     81     84     75     80      76
# p10     62     73     76     77     71     84     84     76     79      75
#
#      ...  r_1_18  r_1_19  r_1_20  r_1_21  r_1_22  r_1_23  r_1_24  r_1_25  \
# p1   ...      63      76      78      73      73      83      70      60
# p2   ...      65      84      84      90      83      85      85      78
# p3   ...      51      84      76      96      72      86      90      81
# p4   ...      55      66      74      71      68      80      68      62
# p5   ...      52      68      82      69      93      95      90      68
# p6   ...      57      87      79      60      72      93      84      67
# p7   ...      62      80      76      79      75      81      70      67
# p8   ...      58      78      76      73      77      91      75      62
# p9   ...      70      82      86      86      79      84      78      81
# p10  ...      68      81      81      74      80      78      70      67
#
#      r_1_26  r_1_27
# p1       73      70
# p2       80      77
# p3       71      63
# p4       61      64
# p5       78      80
# p6       71      76
# p7       72      73
# p8       76      67
# p9       79      85
# p10      77      75
#
# [10 rows x 27 columns]
